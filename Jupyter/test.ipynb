# %% [markdown]
# **IMPORTANDO BIBLIOTECAS**

# %%
import numpy as np
import pandas as pd
import sys

# %% [markdown]
# **PROBANDO**

# %%
a = input("Digite un numero: ")
b = input("Digite un segundo numero: ")

resultado = int(a) + int(b)
print(resultado)

# %% [markdown]
# A
